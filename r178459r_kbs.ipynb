# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r'C:\Users\DELL\Desktop\4.2\kbs\Arrest_Data_from_2010_to_Present.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-652497341368> in <module>()
# ----> 1 df = pd.read_csv(r'C:\Users\DELL\Desktop\4.2\kbs\Arrest_Data_from_2010_to_Present.csv')
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     686     )
#     687
# ...

# %%
df.head()
# Out:
#    Report ID Arrest Date    Time  Area ID  Area Name  Reporting District  \
# 0    4248313  02/24/2015  1310.0     20.0    Olympic              2022.0
# 1  191811472  05/03/2019  1700.0     18.0  Southeast              1802.0
# 2    4254777  02/26/2015  2010.0     19.0    Mission              1985.0
# 3    5614161  04/29/2019  1040.0      8.0    West LA               842.0
# 4    5615197  04/30/2019   615.0      6.0  Hollywood               663.0
#
#     Age Sex Code Descent Code  Charge Group Code Charge Group Description  \
# 0  37.0        M            H                5.0                 Burglary
# 1  23.0        F            B                NaN                      NaN
# 2  22.0        M            H                6.0                  Larceny
# 3  41.0        M            H                3.0                  Robbery
# 4  27.0        M            O                5.0                 Burglary
#
#   Arrest Type Code     Charge Charge Description  \
# ...

# %%
df2018 = df

# %%
df2018.head(3)
# Out:
#    Report ID Arrest Date    Time  Area ID  Area Name  Reporting District  \
# 0    4248313  02/24/2015  1310.0     20.0    Olympic              2022.0
# 1  191811472  05/03/2019  1700.0     18.0  Southeast              1802.0
# 2    4254777  02/26/2015  2010.0     19.0    Mission              1985.0
#
#     Age Sex Code Descent Code  Charge Group Code Charge Group Description  \
# 0  37.0        M            H                5.0                 Burglary
# 1  23.0        F            B                NaN                      NaN
# 2  22.0        M            H                6.0                  Larceny
#
#   Arrest Type Code     Charge Charge Description  \
# 0                F      459PC           BURGLARY
# 1                M  653.22 PC                NaN
# 2                M    459.5PC        SHOPLIFTING
#
#                                    Address Cross Street              Location
# 0                                      5TH       WILTON   (34.0653, -118.314)
# ...

# %%
df2018['Arrest Date'] = pd.to_datetime(df2018['Arrest Date'])

# %%
df2018.head(3)
# Out:
#    Report ID Arrest Date    Time  Area ID  Area Name  Reporting District  \
# 0    4248313  2015-02-24  1310.0     20.0    Olympic              2022.0
# 1  191811472  2019-05-03  1700.0     18.0  Southeast              1802.0
# 2    4254777  2015-02-26  2010.0     19.0    Mission              1985.0
#
#     Age Sex Code Descent Code  Charge Group Code Charge Group Description  \
# 0  37.0        M            H                5.0                 Burglary
# 1  23.0        F            B                NaN                      NaN
# 2  22.0        M            H                6.0                  Larceny
#
#   Arrest Type Code     Charge Charge Description  \
# 0                F      459PC           BURGLARY
# 1                M  653.22 PC                NaN
# 2                M    459.5PC        SHOPLIFTING
#
#                                    Address Cross Street              Location
# 0                                      5TH       WILTON   (34.0653, -118.314)
# ...

# %%
start_date = '2018-01-01'
end_date = '2018-12-31'

# %%
mask = (df2018['Arrest Date'] > start_date) & (df2018['Arrest Date'] <= end_date)

# %%
df2018 = df2018.loc[mask]

# %%
df2018
# Out:
#         Report ID Arrest Date    Time  Area ID    Area Name  \
# 165       5213460  2018-01-24  1930.0      6.0    Hollywood
# 166       5257944  2018-03-15   310.0      7.0     Wilshire
# 167       5328813  2018-06-01  1800.0      3.0    Southwest
# 168       5336331  2018-06-10   200.0     13.0       Newton
# 169       5360731  2018-07-07  2330.0     18.0    Southeast
# 170       5404690  2018-08-25  1850.0     18.0    Southeast
# 171       5406551  2018-08-27  2300.0     18.0    Southeast
# 176       5419122  2018-09-10  1620.0     12.0  77th Street
# 177       5430543  2018-09-23  1830.0     13.0       Newton
# 178       5449454  2018-10-15  2330.0      1.0      Central
# 179       5449463  2018-10-15  2330.0      1.0      Central
# 180       5452727  2018-10-19  1935.0      1.0      Central
# 181       5456681  2018-10-25    30.0      6.0    Hollywood
# 182       5460361  2018-10-29  1550.0     12.0  77th Street
# 183       5464308  2018-11-03   350.0      1.0      Central
# ...

# %%
index = df2018.index

# %%
#number_of_bookings = len(index)
#print(number_of_bookings)

print(len(index), 'bookings of arrestees were made in 2018')
# Out:
# 42144 bookings of arrestees were made in 2018

# %%
print('Area with the most arrests is', df2018['Area ID'].value_counts().idxmax())
# Out:
# Area with the most arrests is 1.0

# %%
area1 = df2018[df2018['Area ID'] == 1.0]

# %%
area1.head(3)
# Out:
#     Report ID Arrest Date    Time  Area ID Area Name  Reporting District  \
# 178   5449454  2018-10-15  2330.0      1.0   Central               157.0
# 179   5449463  2018-10-15  2330.0      1.0   Central               154.0
# 180   5452727  2018-10-19  1935.0      1.0   Central               100.0
#
#       Age Sex Code Descent Code  Charge Group Code Charge Group Description  \
# 178  43.0        M            H                7.0            Vehicle Theft
# 179  32.0        M            H                7.0            Vehicle Theft
# 180  26.0        M            B                7.0            Vehicle Theft
#
#     Arrest Type Code      Charge                Charge Description  \
# 178                F  10851(A)VC  TAKE VEHICLE W/O OWNER'S CONSENT
# 179                F  10851(A)VC  TAKE VEHICLE W/O OWNER'S CONSENT
# 180                F  10851(A)VC  TAKE VEHICLE W/O OWNER'S CONSENT
#
#                              Address Cross Street              Location
# ...

# %%
index_area1 = area1.index

# %%
print(len(index_area1), 'bookings of arrestees were made in the area with the most arrests in 2018, of area ID 1.0')
# Out:
# 5599 bookings of arrestees were made in the area with the most arrests in 2018, of area ID 1.0

# %%
num3 = df2018[[  'Charge Group Code', 'Age', 'Charge Group Description', 'Arrest Date']]

# %%
num3.head(2)
# Out:
#      Charge Group Code   Age Charge Group Description Arrest Date
# 165               10.0  29.0       Fraud/Embezzlement  2018-01-24
# 166                1.0  33.0                 Homicide  2018-03-15

# %%
num3.shape
# Out:
# (42144, 4)

# %%
num3 = num3.dropna(subset = ['Charge Group Description'])

# %%
num3.shape
# Out:
# (30106, 4)

# %%
list1 = [26, 27]

# %%
list1
# Out:
# [26, 27]

# %%
num3 = num3[~num3['Charge Group Code'].isin(list1)]

# %%
num3.shape
# Out:
# (30010, 4)

# %%
#check to see if charge groups 27 and 26 have been removed
num3['Charge Group Code'].unique()
# Out:
# array([10.,  1., 16., 12.,  8., 24.,  7.,  4., 22.,  3.,  5., 15., 23.,
#         6.,  9., 11., 14., 13., 17., 18.,  2., 19., 20., 21., 25.])

# %%
#num3.groupby(['Charge Group Code'])['Age'].mean()

num3.groupby('Charge Group Code', as_index = False).Age.mean()
# Out:
#     Charge Group Code        Age
# 0                 1.0  30.896552
# 1                 2.0  36.203704
# 2                 3.0  27.478261
# 3                 4.0  33.971831
# 4                 5.0  30.350404
# 5                 6.0  32.685452
# 6                 7.0  30.148581
# 7                 8.0  33.430700
# 8                 9.0  34.822034
# 9                10.0  35.729958
# 10               11.0  33.687500
# 11               12.0  29.466761
# 12               13.0  31.629866
# 13               14.0  36.507653
# 14               15.0  36.935252
# 15               16.0  36.110384
# 16               17.0  42.528866
# 17               18.0  44.229891
# 18               19.0  39.727273
# 19               20.0  41.924290
# 20               21.0  40.557047
# 21               22.0  34.364729
# 22               23.0  33.066884
# 23               24.0  36.262631
# 24               25.0  34.600000

# %%
num4 = df2018[df2018['Charge Group Code'].isin([7, 11, 18, 38])]

# %%
num4.shape
# Out:
# (4256, 17)

# %%
num4
# Out:
#          Report ID Arrest Date    Time  Area ID    Area Name  \
# 178        5449454  2018-10-15  2330.0      1.0      Central
# 179        5449463  2018-10-15  2330.0      1.0      Central
# 180        5452727  2018-10-19  1935.0      1.0      Central
# 182        5460361  2018-10-29  1550.0     12.0  77th Street
# 183        5464308  2018-11-03   350.0      1.0      Central
# 184        5471809  2018-11-12  2315.0      1.0      Central
# 185        5476070  2018-11-18   300.0      1.0      Central
# 205        5505591  2018-12-26  1850.0     12.0  77th Street
# 206        5508766  2018-12-30   730.0     13.0       Newton
# 2630       5482424  2018-11-27   720.0     20.0      Olympic
# 2663       5500596  2018-12-20    15.0     18.0    Southeast
# 4734       5218250  2018-01-29  1955.0      6.0    Hollywood
# 4764       5436348  2018-09-30  1200.0     12.0  77th Street
# 4765       5436353  2018-09-30  1200.0     12.0  77th Street
# ...

# %%
num4 = df2018['Age']

# %%
num4.quantile(q = 0.95,   interpolation = 'midpoint')
# Out:
# 61.0

# %%
import statsmodels.api as sm

# %%
felony = df

# %%
start_date = '2010-01-01'
end_date = '2018-12-31'
mask = (felony['Arrest Date'] >= start_date) & (felony['Arrest Date'] <= end_date)
felony = felony.loc[mask]
felony.head()
# Out:
#    Report ID Arrest Date    Time  Area ID    Area Name  Reporting District  \
# 0    4248313  2015-02-24  1310.0     20.0      Olympic              2022.0
# 2    4254777  2015-02-26  2010.0     19.0      Mission              1985.0
# 6    4256466  2015-02-28  1430.0     18.0    Southeast              1824.0
# 7    4256564  2015-02-28  1715.0     10.0  West Valley              1039.0
# 10   4256815  2015-03-01   110.0     17.0   Devonshire              1794.0
#
#      Age Sex Code Descent Code  Charge Group Code Charge Group Description  \
# 0   37.0        M            H                5.0                 Burglary
# 2   22.0        M            H                6.0                  Larceny
# 6   22.0        M            B                5.0                 Burglary
# 7   16.0        M            H                3.0                  Robbery
# 10  22.0        M            H                8.0           Other Assaults
#
#    Arrest Type Code    Charge Charge Description  \
# ...

# %%
felony.shape
# Out:
# (1169706, 17)

# %%
num5 = pd.to_datetime(felony['Arrest Date']).dt.year.value_counts()

# %%
num = pd.DataFrame({'Arrest Year':num5.index, 'count':num5.values})
num
# Out:
#    Arrest Year   count
# 0         2012  163313
# 1         2010  162399
# 2         2011  157637
# 3         2013  152671
# 4         2014  139379
# 5         2015  126154
# 6         2016  118125
# 7         2017  107647
# 8         2018   42381

# %%
import seaborn as sns

# %%
data = num
plt.rcParams['figure.figsize'] = [18, 8]
data.plot(x = 'Arrest Year', y = 'count', fontsize = 30)
plt.xlabel('Arrest Year', fontsize = 30)
sns.regplot(x='Arrest Year', y = 'count', data = data, fit_reg=True)
# Out:
# C:\Users\DELL\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
x = data['Arrest Year']
y = data['count']
x = sm.add_constant(x)
model = sm.OLS(y, x).fit()
predictions = model.predict(x)
print_model = model.summary()
print(print_model)
# Out:
# C:\Users\DELL\Anaconda3\lib\site-packages\scipy\stats\stats.py:1394: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=9
#   "anyway, n=%i" % int(n))
#                             OLS Regression Results
# ...
# Dep. Variable:                  count   R-squared:                       0.784
# Model:                            OLS   Adj. R-squared:                  0.753
# Method:                 Least Squares   F-statistic:                     25.43
# Date:                Thu, 20 May 2021   Prob (F-statistic):            0.00149
# Time:                        10:28:13   Log-Likelihood:                -100.37
# No. Observations:                   9   AIC:                             204.7
# Df Residuals:                       7   BIC:                             205.1
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                   coef    std err          t      P>|t|      [0.025      0.975]
# ...

# %%
pd.to_datetime(df['Arrest Date']).dt.year.value_counts()
# Out:
# 2012.0    163313
# 2010.0    162399
# 2011.0    157637
# 2013.0    152671
# 2014.0    139379
# 2015.0    126154
# 2016.0    118125
# 2017.0    107647
# 2019.0     57811
# 2018.0     42381
# Name: Arrest Date, dtype: int64

# %%
#2019 prediction from y = mx + c
#count=(const coef) + (Arrest Year coef)*x
count = (2.52e+07) + (-1.245e+04)*57811
print(count)
# Out:
# -694546950.0

# %%
from math import radians, cos, sin, asin, sqrt

# %%
def haversine_distance(lat1, lon1, lat2, lon2):
    r = 6371
    phi1 = np.radians(lat1)
    phi2 = np.radians(lat2)
    delta_phi = np.radians(lat2 -lat1)
    delta_lambda = np.radians(lon2 - lon1)
    a = np.sin(delta_phi / 2)**2 + np.cos(phi1)* np.cos(phi2)* np.sin(delta_lambda /2)**2
    res = r * (2 * np.arctan2(np.sqrt(a), np.sqrt(1 -a)))
    return np.round(res, 2)

# %%
num6 = df2018

# %%
num6.head(2)
# Out:
#     Report ID Arrest Date    Time  Area ID  Area Name  Reporting District  \
# 165   5213460  2018-01-24  1930.0      6.0  Hollywood               668.0
# 166   5257944  2018-03-15   310.0      7.0   Wilshire               743.0
#
#       Age Sex Code Descent Code  Charge Group Code Charge Group Description  \
# 165  29.0        M            H               10.0       Fraud/Embezzlement
# 166  33.0        F            O                1.0                 Homicide
#
#     Arrest Type Code      Charge                         Charge Description  \
# 165                F  530.5(A)PC                  GET CREDIT/ETC OTHER'S ID
# 166                F  191.5(B)PC  VEH MANSLAUGHTR/OPER VESSEL DUI & DUR FEL
#
#         Address Cross Street              Location
# 165  ST ANDREWS     FOUNTAIN  (34.0949, -118.3109)
# 166     OLYMPIC     MASSELIN  (34.0574, -118.3547)

# %%
num61 = num6['Location'].str.strip('()')             \
.str.split(', ', expand=True)                 \
.rename(columns={0:'Latitude', 1:'Longitude'})

# %%
num61 = num61.dropna(axis=0)

# %%
from scipy import special
from math import radians
from sklearn.neighbors import DistanceMetric
from math import radians, cos, sin, asin, sqrt

# %%
num61['Longitude'].astype(float)
# Out:
# 165       -118.3109
# 166       -118.3547
# 167       -118.3061
# 168       -118.2543
# 169       -118.2739
# 170       -118.2739
# 171       -118.2805
# 176       -118.3265
# 177       -118.2686
# 178       -118.2440
# 179       -118.2509
# 180       -118.2517
# 181       -118.3494
# 182       -118.2871
# 183       -118.2386
# 184       -118.2407
# 185       -118.2598
# 186       -118.2937
# 187       -118.2440
# 188       -118.2494
# 189       -118.2827
# 190       -118.4655
# 191       -118.2878
# 192       -118.2471
# 193       -118.2936
# 194       -118.2899
# 195       -118.2842
# 196       -118.2652
# 197       -118.3002
# 198       -118.2975
#              ...
# 1227486   -118.3288
# 1227487   -118.3387
# 1227488   -118.2811
# 1227489   -118.4609
# 1227490   -118.2571
# 1227491   -118.3109
# 1227492   -118.2010
# 1227493   -118.4012
# 1227494   -118.2434
# 1227495   -118.3046
# 1227496   -118.2304
# 1227497   -118.3818
# 1227498   -118.4362
# 1227499   -118.2196
# ...

# %%
num61['Latitude'].astype(float)
# Out:
# 165        34.0949
# 166        34.0574
# 167        34.0219
# 168        33.9980
# 169        33.9392
# 170        33.9402
# 171        33.9374
# 176        33.9757
# 177        34.0289
# 178        34.0416
# 179        34.0460
# 180        34.0413
# 181        34.1007
# 182        34.0027
# 183        34.0350
# 184        34.0444
# 185        34.0402
# 186        34.0006
# 187        34.0096
# 188        34.0495
# 189        33.9965
# 190        34.0536
# 191        34.0728
# 192        34.0435
# 193        34.0473
# 194        34.0670
# 195        34.0588
# 196        33.9966
# 197        34.0255
# 198        34.0246
#             ...
# 1227486    34.0835
# 1227487    34.1016
# 1227488    34.0167
# 1227489    34.0495
# 1227490    34.0219
# 1227491    34.0918
# 1227492    34.0685
# 1227493    34.1687
# 1227494    34.0522
# 1227495    33.9992
# 1227496    34.0182
# 1227497    34.0425
# 1227498    34.2297
# 1227499    34.0415
# 1227500    34.0252
# 1227501    34.0443
# ...

# %%
num61.head(5)
# Out:
#     Latitude  Longitude
# 165  34.0949  -118.3109
# 166  34.0574  -118.3547
# 167  34.0219  -118.3061
# 168   33.998  -118.2543
# 169  33.9392  -118.2739

# %%
from math import radians, cos, sin, asin, sqrt

# %%
import math

# %%
def haversine_distance(lat1, lon1, lat2, lon2):
    r = 6371
    phi1 = np.radians(lat1)
    phi2 = np.radians(lat2)
    delta_phi = np.radians(lat2 -lat1)
    delta_lambda = np.radians(lon2 - lon1)
    a = np.sin(delta_phi / 2)**2 + np.cos(phi1)* np.cos(phi2)* np.sin(delta_lambda /2)**2
    res = r * (2 * np.arctan2(np.sqrt(a), np.sqrt(1 -a)))
    return np.round(res, 2)

# %%
start_lat, start_lon = math.radians(int(float(40.6976637))), math.radians(int(float((-74.1197643))))

# %%
distances_km = []
for x in num61.itertuples():
    distances_km.append(haversine_distance(34.050536,-118.247861, math.radians(int(float(x.Latitude))),math.radians( int(float(x.Longitude)))))

# %%
len(distances_km)
# Out:
# 42143

# %%
bradbury_building_lat_lon=(34.050536,-118.247861, )
#num61['distance'] = num61.apply(haversine_distance, args=(bradbury_building_lat_lon, math.radians(int(float(x.Latitude))),math.radians( int(float(x.Longitude)))))
#num61[num61['distance']<=2]

# %%
df2018.head(2)
# Out:
#     Report ID Arrest Date    Time  Area ID  Area Name  Reporting District  \
# 165   5213460  2018-01-24  1930.0      6.0  Hollywood               668.0
# 166   5257944  2018-03-15   310.0      7.0   Wilshire               743.0
#
#       Age Sex Code Descent Code  Charge Group Code Charge Group Description  \
# 165  29.0        M            H               10.0       Fraud/Embezzlement
# 166  33.0        F            O                1.0                 Homicide
#
#     Arrest Type Code      Charge                         Charge Description  \
# 165                F  530.5(A)PC                  GET CREDIT/ETC OTHER'S ID
# 166                F  191.5(B)PC  VEH MANSLAUGHTR/OPER VESSEL DUI & DUR FEL
#
#         Address Cross Street              Location
# 165  ST ANDREWS     FOUNTAIN  (34.0949, -118.3109)
# 166     OLYMPIC     MASSELIN  (34.0574, -118.3547)

# %%
num7 = df2018[df2018['Address'].str.contains('PICO', na=False)]

# %%
num7.head(2)
# Out:
#      Report ID Arrest Date    Time  Area ID Area Name  Reporting District  \
# 193    5485873  2018-12-01  1350.0     20.0   Olympic              2076.0
# 4738   5270090  2018-03-29   931.0      8.0   West LA               836.0
#
#        Age Sex Code Descent Code  Charge Group Code Charge Group Description  \
# 193   37.0        M            B                8.0           Other Assaults
# 4738  53.0        M            W                6.0                  Larceny
#
#      Arrest Type Code    Charge                         Charge Description  \
# 193                 M  243(B)PC  BATTERY ON PO/EMERGENCY PERSONNEL W/O INJ
# 4738                F  487(A)PC          GRAND THEFT MONEY/PROPERTY > $400
#
#                               Address                     Cross Street  \
# 193   PICO                         BL  BERENDO                      ST
# 4738  PICO                         BL  PROSSER                      ST
#
#                   Location
# 193   (34.0473, -118.2936)
# ...

# %%
num7.shape
# Out:
# (268, 17)

# %%
num71 = num7['Location'].str.strip('()').str.split(', ', expand=True).rename(columns={0:'Latitude', 1:'Longitude'})

# %%
num71.head(2)
# Out:
#      Latitude  Longitude
# 193   34.0473  -118.2936
# 4738  34.0524  -118.4248

# %%
from scipy.stats import zscore

# %%
mean_latitude = pd.to_numeric(num71['Latitude'], errors='coerce').mean()

# %%
print(mean_latitude)
# Out:
# 34.040277238805984

# %%
mean_longitude = pd.to_numeric(num71['Longitude'], errors='coerce').mean()

# %%
print(mean_longitude)
# Out:
# -118.36961529850741

# %%
most_western = pd.to_numeric(num71['Longitude'], errors='coerce').max()

# %%
most_western
# Out:
# -118.1785

# %%
most_eastern = pd.to_numeric(num71['Latitude'], errors='coerce').max()

# %%
most_eastern
# Out:
# 34.0887

# %%
num71.head(2)
# Out:
#      Latitude  Longitude
# 193   34.0473  -118.2936
# 4738  34.0524  -118.4248

# %%
num71['Longitude'] = pd.to_numeric( num71['Longitude'], errors='coerce')

# %%
num71['Latitude'] = pd.to_numeric( num71['Latitude'], errors='coerce')

# %%
num71.head(2)
# Out:
#       Latitude  Longitude
# 193    34.0473  -118.2936
# 4738   34.0524  -118.4248

# %%
print(num71['Latitude'].std())
# Out:
# 0.008978770458086153

# %%
print(num71['Longitude'].std())
# Out:
# 0.07468394397677075

# %%
sd1 = np.std(num71['Latitude'], axis=0)

# %%
sd1
# Out:
# 0.008962003365101685

# %%
sd2 = np.std(num71['Longitude'], axis=0)

# %%
sd2
# Out:
# 0.07454447803998676

# %%
final_lat = [x for x in num71['Latitude'] if (x > mean_latitude -2 *sd1)]

# %%
final_long = [x for x in num71['Longitude'] if (x > mean_longitude -2 *sd2)]

# %%
z_scores = stats.zscore(num71)
abs_z_scores = np.abs(z_scores)
filtered_entries = (abs_z_scores < 3)
new_df = num71[filtered_entries]
new_df.drop_duplicates(subset = 'Latitude', keep = 'first', inplace = True)
print(new_df)
# Out:
#          Latitude  Longitude
# 193       34.0473  -118.2936
# 4738      34.0524  -118.4248
# 6685      34.0472  -118.3090
# 6768      34.0515  -118.3667
# 10805     34.0485  -118.3335
# 52687     34.0401  -118.2668
# 60768     34.0467  -118.2814
# 60842     34.0452  -118.4190
# 60894     34.0369  -118.2607
# 60977     34.0479  -118.3447
# 61074     34.0437  -118.2748
# 422837    34.0363  -118.2672
# 423148    34.0420  -118.2625
# 423836    34.0389  -118.2643
# 424914    34.0335  -118.2619
# 424958    34.0395  -118.2656
# 425848    34.0388  -118.2574
# 426353    34.0352  -118.2583
# 426707    34.0407  -118.2680
# 426990    34.0451  -118.2779
# 427223    34.0433  -118.2740
# 427590    34.0442  -118.2758
# 429347    34.0460  -118.2799
# 429521    34.0446  -118.2769
# 429773    34.0447  -118.2771
# 433082    34.0887  -118.1785
# 438044    34.0347  -118.4397
# 438055    34.0370  -118.4351
# 438058    34.0281  -118.4530
# 438080    34.0294  -118.4502
# ...           ...        ...
# ...

# %%
from math import radians, cos, sin, asin, sqrt

# %%
def distance(lat1, lon1, lat2, lon2):
    r = 6371
    phi1 = np.radians(lat1)
    phi2 = np.radians(lat2)
    delta_phi = np.radians(lat2 -lat1)
    delta_lambda = np.radians(lon2 - lon1)
    a = np.sin(delta_phi / 2)**2 + np.cos(phi1)* np.cos(phi2)* np.sin(delta_lambda /2)**2
    res = r * (2 * np.arctan2(np.sqrt(a), np.sqrt(1 -a)))
    return np.round(res, 2)

# %%
distance(34.048471, -118.355903, 34.0887, -118.1785 )
# Out:
# 16.94

# %%
print(len(new_df), 'arrests occured per kilometer on pico boulevard')
# Out:
# 74 arrests occured per kilometer on pico boulevard
