# %%
import numpy as np
import pandas as pd

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-e1f8ab2e-1678-47f5-8b4c-f654d84f588c" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-e1f8ab2e-1678-47f5-8b4c-f654d84f588c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving movies (1).csv to movies (1).csv
# Saving ratings (1).csv to ratings (1).csv

# %%
import io
mov = pd.read_csv(io.BytesIO(uploaded['movies (1).csv']))
rat = pd.read_csv(io.BytesIO(uploaded['ratings (1).csv']))

# %%
mov.head()
# Out:
#    movieId  ...                                       genres
# 0        1  ...  Adventure|Animation|Children|Comedy|Fantasy
# 1        2  ...                   Adventure|Children|Fantasy
# 2        3  ...                               Comedy|Romance
# 3        4  ...                         Comedy|Drama|Romance
# 4        5  ...                                       Comedy
#
# [5 rows x 3 columns]

# %%
rat.head()
# Out:
#    userId  movieId  rating  timestamp
# 0       1        1     4.0  964982703
# 1       1        3     4.0  964981247
# 2       1        6     4.0  964982224
# 3       1       47     5.0  964983815
# 4       1       50     5.0  964982931

# %%
movierating = (pd.merge(mov, rat, on='movieId'))

# %%
movierating.head()
# Out:
#    movieId             title  ... rating   timestamp
# 0        1  Toy Story (1995)  ...    4.0   964982703
# 1        1  Toy Story (1995)  ...    4.0   847434962
# 2        1  Toy Story (1995)  ...    4.5  1106635946
# 3        1  Toy Story (1995)  ...    2.5  1510577970
# 4        1  Toy Story (1995)  ...    4.5  1305696483
#
# [5 rows x 6 columns]

# %%
movierating.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 100836 entries, 0 to 100835
# Data columns (total 6 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   movieId    100836 non-null  int64
#  1   title      100836 non-null  object
#  2   genres     100836 non-null  object
#  3   userId     100836 non-null  int64
#  4   rating     100836 non-null  float64
#  5   timestamp  100836 non-null  int64
# dtypes: float64(1), int64(3), object(2)
# memory usage: 5.4+ MB

# %%
movierating.describe()
# Out:
#              movieId         userId         rating     timestamp
# count  100836.000000  100836.000000  100836.000000  1.008360e+05
# mean    19435.295718     326.127564       3.501557  1.205946e+09
# std     35530.987199     182.618491       1.042529  2.162610e+08
# min         1.000000       1.000000       0.500000  8.281246e+08
# 25%      1199.000000     177.000000       3.000000  1.019124e+09
# 50%      2991.000000     325.000000       3.500000  1.186087e+09
# 75%      8122.000000     477.000000       4.000000  1.435994e+09
# max    193609.000000     610.000000       5.000000  1.537799e+09

# %%
movierating.isnull().sum()
# Out:
# movieId      0
# title        0
# genres       0
# userId       0
# rating       0
# timestamp    0
# dtype: int64

# %%
X = movierating[['userId']]
Y = movierating['movieId']

# %%
from numpy import loadtxt
from keras.models import Sequential
from keras.layers import Dense
import pandas as pd

# %%
model = Sequential()
model.add(Dense(12, input_dim=2, activation='relu'))
model.add(Dense(8, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

# %%
from sklearn.preprocessing import OneHotEncoder, LabelEncoder



# binary encode
label_encoder = LabelEncoder()
encodedY = label_encoder.fit_transform(Y).reshape(-1,1)

# %%
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
model.fit(X, Y, epochs=75,batch_size=15)
# Out:
# Epoch 1/75
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-22-abcdc4678504> in <module>()
#       1 model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
# ----> 2 model.fit(X, Y, epochs=75,batch_size=15)
#
# /usr/local/lib/python3.7/dist-packages/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1182                 _r=1):
#    1183               callbacks.on_train_batch_begin(step)
# -> 1184               tmp_logs = self.train_function(iterator)
#    1185               if data_handler.should_sync:
#    1186                 context.async_wait()
#
# ...

# %%
_, accuracy = model.evaluate(X, encodedY)
print('Accuracy: %.2f' % (accuracy*100))

# %%
import numpy as np
from sklearn import metrics
predictions = model.predict(X)
# round predictions 
# rounded = [round(x[0]) for x in predictions]
predictions = model.predict_classes(X)

# %%
Recognize whether a column is numerical or categorical.
:parameter
    :param dtf: dataframe - input data
    :param col: str - name of the column to analyze
    :param max_cat: num - max number of unique values to recognize a column as categorical
:return
    "cat" if the column is categorical or "num" otherwise
'''
def utils_recognize_type(dtf, col, max_cat=20):
    if (dtf[col].dtype == "O") | (dtf[col].nunique() < max_cat):
        return "cat"
    else:
        return "num"
