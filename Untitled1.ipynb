# %%
# !pip install -U ipykernel
# Out:
# ...
#      |████████████████████████████████| 122kB 4.2MB/s
# ...
# ERROR: google-colab 1.0.0 has requirement ipykernel~=4.10, but you'll have ipykernel 5.5.5 which is incompatible.
# ...
#   Found existing installation: ipykernel 4.10.1
#     Uninstalling ipykernel-4.10.1:
#       Successfully uninstalled ipykernel-4.10.1
# ...

# %%
# !pip3 install -U pip
# !pip3 install streamlit
# !pip3 install streamlit-agraph
# Out:
# ...
#      |████████████████████████████████| 1.6MB 4.4MB/s
# ...
#   Found existing installation: pip 19.3.1
#     Uninstalling pip-19.3.1:
#       Successfully uninstalled pip-19.3.1
# ...
#      |████████████████████████████████| 7.7 MB 4.2 MB/s
# ...
#      |████████████████████████████████| 111 kB 45.7 MB/s
# ...
#      |████████████████████████████████| 170 kB 41.2 MB/s
# ...
#      |████████████████████████████████| 4.2 MB 51.3 MB/s
# ...
#      |████████████████████████████████| 74 kB 2.6 MB/s
# ...
#      |████████████████████████████████| 63 kB 1.6 MB/s
# ...
#   Created wheel for blinker: filename=blinker-1.4-py3-none-any.whl size=13479 sha256=54807041c4ac9fda53001be648f495ebd3ed1c645bba3b0f54ac810810a28e30
#   Stored in directory: /root/.cache/pip/wheels/22/f5/18/df711b66eb25b21325c132757d4314db9ac5e8dabeaf196eab
# Successfully built blinker
# ...
# WARNING: Running pip as root will break packages and permissions. You should install packages reliably by using venv: https://pip.pypa.io/warnings/venv
# ...

# %%
# !pip install pyngrok
# Out:
# ...
#      |████████████████████████████████| 745 kB 4.3 MB/s
# ...
#   Created wheel for pyngrok: filename=pyngrok-5.0.5-py3-none-any.whl size=19262 sha256=0791162d16b4bb16d69ef9af74c886595c5433fd16ed3c24cc43252502ef37fd
#   Stored in directory: /root/.cache/pip/wheels/1b/f7/72/35c95a53d15b91dd00df6cf1304d49a31ec5ed6f954c2d4e32
# Successfully built pyngrok
# ...
# WARNING: Running pip as root will break packages and permissions. You should install packages reliably by using venv: https://pip.pypa.io/warnings/venv

# %%
pyngrok authtoken 1u8ASTjA6c4lKrsZqJP5AeSvolI_3JXXJkRARJREa3nGKiXwz
# Out:
#   File "<ipython-input-11-809fc1053270>", line 1
#     pyngrok authtoken 1u8ASTjA6c4lKrsZqJP5AeSvolI_3JXXJkRARJREa3nGKiXwz
#                     ^
# SyntaxError: invalid syntax

# %%
SHOW CODE
# Out:
#   File "<ipython-input-12-1267b27361d7>", line 1
#     SHOW CODE
#             ^
# SyntaxError: invalid syntax

# %%
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import tensorflow as tf
import numpy as np
import streamlit as st
from PIL import image
import requests
from io import BytesIO

st.set_option('deprecation.showfileUploaderEncoding', False)
st.title("Bean Image Detector")
st.text("Provide URL of bean for image classifier")

@st.cache(allow_output_mutation=True)
def load_mode():
  model = tf.keras.models.load.model('/content/drive/My Drive/Colab Notebooks/models/image/models')
  return model

with st.spinner('Loading Model Into Memory...'):
  model = load_model()

classes['angular_leaff_spot', 'bean_rust', 'healthy']

def scale(image):
  image = tf.cast(image, tf.float32)
  image/= 255.0

  return tf.image.resize(image,[224,224])

def decode_img(image):
  img = tf.image.decode_jpeg(image, channels=3)
  img = scale(img)
  return np.expand_dims(img, axis=0)

path = st.text_input('Enter Video URL to detect health status of bean leafs...','http://barmac.com.au/wp.content/uploads/sites/3/2016/01/Angular-Leaf-S...')
if path is not None:
  content = requests.get(path).content

  st.write("Predicted class:")
  with st.spinner('Classifying....'):
    label =np.argmax(model.predict(decode_img(content)), axis=1)
    st.write(classes[label[0]])
  st.write("")
  image = Image.open(BytesIO(content))
  st.image(image, caption='Classifying Bean Image', use_column_width = True )
# Out:
# ---------------------------------------------------------------------------
# ContextualVersionConflict                 Traceback (most recent call last)
# <ipython-input-12-6c33b1be4a4d> in <module>()
#       1 import tensorflow as tf
#       2 import numpy as np
# ----> 3 import streamlit as st
#       4 from PIL import image
#       5 import requests
#
# /usr/local/lib/python3.7/dist-packages/streamlit/__init__.py in <module>()
#      58 # This used to be pkg_resources.require('streamlit') but it would cause
#      59 # pex files to fail. See #394 for more details.
# ---> 60 __version__ = _pkg_resources.get_distribution("streamlit").version
#      61
#      62 import contextlib as _contextlib
#
# /usr/local/lib/python3.7/dist-packages/pkg_resources/__init__.py in get_distribution(dist)
#     464         dist = Requirement.parse(dist)
#     465     if isinstance(dist, Requirement):
# --> 466         dist = get_provider(dist)
#     467     if not isinstance(dist, Distribution):
# ...
