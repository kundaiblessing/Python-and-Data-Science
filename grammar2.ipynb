# %%
P : : = bSe;
S -> AR;
R -> AR | @;
A -> a=E;
E -> FT
T -> +FT | @;
F -> (E) | a | r
# Out:
#   File "<ipython-input-2-b41c29736555>", line 1
#     P -> bSe;
#        ^
# SyntaxError: invalid syntax
